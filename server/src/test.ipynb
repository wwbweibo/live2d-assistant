# %%
from utils.selenium import WebDriverManager
from bs4 import BeautifulSoup
from search import BingSearchEngine
from llm_adapters import OllamaAdapter
import logging

logger = logging.getLogger(__name__)

# %%
ollama_adapter = OllamaAdapter("http://localhost:11434", logger)

# %%
search_engine = BingSearchEngine(ollama_adapter, "qwen2.5:7b")
result = await search_engine.searh_workflow("我想学习Python的单元测试，应该怎么学？")
print(result)
# Out:
# 提取的查询语句： 搜索查询语句：学习 Python 单元测试 方法步骤
# 搜索结果： [<search.search_engine.SearchResultItem object at 0x10960f8c0>, <search.search_engine.SearchResultItem object at 0x1095f8b90>, <search.search_engine.SearchResultItem object at 0x1095fa5d0>, <search.search_engine.SearchResultItem object at 0x10921b360>, <search.search_engine.SearchResultItem object at 0x10921b6f0>, <search.search_engine.SearchResultItem object at 0x109754dd0>, <search.search_engine.SearchResultItem object at 0x1095b2f10>, <search.search_engine.SearchResultItem object at 0x1095b3130>, <search.search_engine.SearchResultItem object at 0x10974ed50>]
# 最符合用户搜索意图的搜索结果： [2, 4, 6, 8, 3]
# 第 1 次尝试获取页面内容时发生错误: Message:
#
# ...
