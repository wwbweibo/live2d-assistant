# %%
from utils.selenium import WebDriverManager
from bs4 import BeautifulSoup
from search import BingSearchEngine
from llm import OllamaClient

# %%
ollama_client = OllamaClient("http://localhost:11434")

# %%
search_engine = BingSearchEngine(ollama_client, "deepseek-r1:1.5b")
result = search_engine.searh_workflow("我想学习Python的单元测试，应该怎么学？")
print(result)
# Out:
# 提取的查询语句： Python 单元测试 学习方法
# 搜索结果： [<search.SearchResultItem object at 0x10aa45e80>, <search.SearchResultItem object at 0x10a98a5d0>, <search.SearchResultItem object at 0x10a98ac10>, <search.SearchResultItem object at 0x10a8bbce0>, <search.SearchResultItem object at 0x10a8bbe10>, <search.SearchResultItem object at 0x10ad220f0>, <search.SearchResultItem object at 0x10a973680>, <search.SearchResultItem object at 0x10a973ac0>, <search.SearchResultItem object at 0x10ad24650>, <search.SearchResultItem object at 0x10ad24750>]
# 最符合用户搜索意图的搜索结果： 1,4,6,7,9
# 获取页面内容时发生错误: Message:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 search_engine = BingSearchEngine(ollama_client, "deepseek-r1:8b")
# ----> 2 result = search_engine.searh_workflow("我想学习Python的单元测试，应该怎么学？")
#       3 print(result)
#
# File ~/code/myself/live2d-assistant/py_script/search.py:88, in BaseSearchEngine.searh_workflow(self, text)
#      86 print("最符合用户搜索意图的搜索结果：", top_result)
#      87 selected_result_idx = [int(idx) for idx in top_result.split(',')]
# ---> 88 selected_result_detail = self.read_search_result_detail(result_list, selected_result_idx)
#      89 print("选中的搜索结果详情：", selected_result_detail)
#      90 return selected_result_detail
#
# File ~/code/myself/live2d-assistant/py_script/search.py:66, in BaseSearchEngine.read_search_result_detail(self, search_result, selected_result_idx)
#      64 detail_list = []
#      65 for idx in selected_result_idx:
# ---> 66     search_result_detail = self.get_search_result_detail(search_result[idx - 1])
#      67     detail_list.append(search_result_detail)
#      68 return detail_list
#
# File ~/code/myself/live2d-assistant/py_script/search.py:73, in BaseSearchEngine.get_search_result_detail(self, search_result)
#      71 with WebDriverManager() as driver:
#      72     content = driver.get_page_content(search_result.url)
# ---> 73     soup = BeautifulSoup(content, 'html.parser')
#      74     return soup.text
#
# File ~/code/myself/live2d-assistant/venv/lib/python3.13/site-packages/bs4/__init__.py:442, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     440     markup = markup.read()
#     441 elif not isinstance(markup, (bytes, str)) and not hasattr(markup, "__len__"):
# --> 442     raise TypeError(
#     443         f"Incoming markup is of an invalid type: {markup!r}. Markup must be a string, a bytestring, or an open filehandle."
#     444     )
#     445 elif len(markup) <= 256 and (
#     446     (isinstance(markup, bytes) and b"<" not in markup and b"\n" not in markup)
#     447     or (isinstance(markup, str) and "<" not in markup and "\n" not in markup)
#    (...)
#     451     # Beautiful Soup will still parse the input as markup,
#     452     # since that is sometimes the intended behavior.
#     453     if not self._markup_is_url(markup):
#
# TypeError: Incoming markup is of an invalid type: None. Markup must be a string, a bytestring, or an open filehandle.
